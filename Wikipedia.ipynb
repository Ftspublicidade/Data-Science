# %% [markdown]
# # Análise de dados da Copa do Mundo
# Com base na página sobre a copa do mundo na Wikipedia vamos obter os dados de público
#
# link -> https://pt.wikipedia.org/wiki/Copa_do_Mundo_FIFA

# %%
#Importando as bibliotecas
import pandas as pd
import requests

#URL
url = "https://pt.wikipedia.org/wiki/Copa_do_Mundo_FIFA"

# Requisitar a página e guardar a resposta
resposta = requests.get(url)

# Exibir
resposta.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="pt" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Copa do Mundo FIFA – Wikipédia, a enciclopédia livre</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Copa_do_Mundo_FIFA","wgTitle":"Copa do Mundo FIFA","wgCurRevisionId":54259445,"wgRevisionId":54259445,"wgArticleId":6133,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["!CS1 inglês-fontes em língua (en)","!Artigos com ligações inativas","!Artigos com citações quebradas","!Artigos destacados na Wikipédia em letão","!Artigos destacados na Wikipédia em scots","!Artigos destacados na Wikipédia em tailandês","!Artigos destacados na Wikipédia em indonésio
# ...

# %%
# Obter a resposta em formato HTML
table = pd.read_html(resposta.text)
table
# Out:
# [                                                    0  \
#  0    Copa do Mundo (pt-BR)Campeonato do Mundo (pt-EU)
#  1                                        Dados gerais
#  2                                         Organização
#  3                                             Edições
#  4                                    Local de disputa
#  5                                             Sistema
#  6   Dados históricos  Primeiro vencedor  Uruguai (...
#  7                                    Dados históricos
#  8                                   Primeiro vencedor
#  9                                     Último vencedor
#  10  Estatísticas  Total de gol(o)s 2 548  Total de...
#  11                                       Estatísticas
#  12                                   Total de gol(o)s
#  13                                     Total de jogos
#  14                                              Média
#  15                                       Edição atual
# ...

# %%
df = table[3]
df.head()
# Out:
#          0        1                 2             3         4             5  \
# 0      Ano     Sede  Estádios/Cidades  Públicototal  Partidas  Públicomédio
# 1  Público  Estádio           Jogo(s)           NaN       NaN           NaN
# 2     1930  Uruguai               3/1       590 549        18        32 808
# 3     1934   Itália               8/8       363 000        17        21 353
# 4     1938   França              10/9       375 700        18        20 872
#
#                   6                               7  \
# 0  Maiores públicos                             NaN
# 1               NaN                             NaN
# 2            93 000  Estadio Centenário, Montevidéu
# 3            55 000  Stadio Nazionale del PNF, Roma
# 4            58 455    Olympique de Colombes, Paris
#
#                                      8
# 0                                  NaN
# 1                                  NaN
# 2    Uruguay 6–1 Iugoslávia, Semifinal
# ...

# %%
df.columns = df.iloc[0]
df.head()
# Out:
# 0      Ano     Sede  Estádios/Cidades  Públicototal  Partidas  Públicomédio  \
# 0      Ano     Sede  Estádios/Cidades  Públicototal  Partidas  Públicomédio
# 1  Público  Estádio           Jogo(s)           NaN       NaN           NaN
# 2     1930  Uruguai               3/1       590 549        18        32 808
# 3     1934   Itália               8/8       363 000        17        21 353
# 4     1938   França              10/9       375 700        18        20 872
#
# 0  Maiores públicos                             NaN  \
# 0  Maiores públicos                             NaN
# 1               NaN                             NaN
# 2            93 000  Estadio Centenário, Montevidéu
# 3            55 000  Stadio Nazionale del PNF, Roma
# 4            58 455    Olympique de Colombes, Paris
#
# 0                                  NaN
# 0                                  NaN
# 1                                  NaN
# 2    Uruguay 6–1 Iugoslávia, Semifinal
# ...

# %%
df.isnull().sum()
# Out:
# 0
# Ano                 0
# Sede                0
# Estádios/Cidades    0
# Públicototal        1
# Partidas            1
# Públicomédio        1
# Maiores públicos    2
# NaN                 3
# NaN                 3
# dtype: int64

# %%
df.drop(df.index[0], inplace = True)

# %%
df.head()
# Out:
# 0      Ano     Sede Estádios/Cidades Públicototal Partidas Públicomédio  \
# 1  Público  Estádio          Jogo(s)          NaN      NaN          NaN
# 2     1930  Uruguai              3/1      590 549       18       32 808
# 3     1934   Itália              8/8      363 000       17       21 353
# 4     1938   França             10/9      375 700       18       20 872
# 5     1950   Brasil              6/6    1 045 246       22       47 511
#
# 0 Maiores públicos                                  NaN  \
# 1              NaN                                  NaN
# 2           93 000       Estadio Centenário, Montevidéu
# 3           55 000       Stadio Nazionale del PNF, Roma
# 4           58 455         Olympique de Colombes, Paris
# 5      173 850[56]  Estádio do Maracanã, Rio de Janeiro
#
# 0                                     NaN
# 1                                     NaN
# 2       Uruguay 6–1 Iugoslávia, Semifinal
# 3        Italia 2–1 Checoslováquia, Final
# ...

# %%
df.columns = ["Ano", "Sede", "Estádios/Cidades", "Partidas", "Público médio", "Maiores Públicos", "Público", "Estádio", "Jogo(s)"]

# %%
df.head()
# Out:
#     Ano    Sede Estádios/Cidades   Partidas Público médio Maiores Públicos  \
# 3  1934  Itália              8/8    363 000            17           21 353
# 4  1938  França             10/9    375 700            18           20 872
# 5  1950  Brasil              6/6  1 045 246            22           47 511
# 6  1954   Suíça              6/6    768 607            26           29 562
# 7  1958  Suécia            12/12    819 810            35           23 423
#
#        Público                              Estádio  \
# 3       55 000       Stadio Nazionale del PNF, Roma
# 4       58 455         Olympique de Colombes, Paris
# 5  173 850[56]  Estádio do Maracanã, Rio de Janeiro
# 6       63 000              Wankdorf Stadium, Berna
# 7       50 928           Ullevi Stadium, Gothenburg
#
#                                       Jogo(s)
# 3            Italia 2–1 Checoslováquia, Final
# 4         França 1–3 Italia, Quartas de final
# 5      Brasil 1–2 Uruguai, quadrangular final
# ...

# %%
df.drop(df.index[0], inplace=True)

# %%
df.head()
# Out:
#     Ano    Sede Estádios/Cidades   Partidas Público médio Maiores Públicos  \
# 3  1934  Itália              8/8    363 000            17           21 353
# 4  1938  França             10/9    375 700            18           20 872
# 5  1950  Brasil              6/6  1 045 246            22           47 511
# 6  1954   Suíça              6/6    768 607            26           29 562
# 7  1958  Suécia            12/12    819 810            35           23 423
#
#        Público                              Estádio  \
# 3       55 000       Stadio Nazionale del PNF, Roma
# 4       58 455         Olympique de Colombes, Paris
# 5  173 850[56]  Estádio do Maracanã, Rio de Janeiro
# 6       63 000              Wankdorf Stadium, Berna
# 7       50 928           Ullevi Stadium, Gothenburg
#
#                                       Jogo(s)
# 3            Italia 2–1 Checoslováquia, Final
# 4         França 1–3 Italia, Quartas de final
# 5      Brasil 1–2 Uruguai, quadrangular final
# ...

# %%
df["Estádio"].value_counts()
# Out:
# Estádio do Maracanã, Rio de Janeiro          2
# Estádio Azteca, Cidade do México             2
# Olympiastadion, Berlim                       1
# Luzhniki Stadium, Moscou                     1
# Olympiastadion, Berlim Ocidental             1
# Olympique de Colombes, Paris                 1
# Soccer City, Joanesburgo                     1
# Ullevi Stadium, Gothenburg                   1
# Estadio Nacional, Santiago                   1
# San Siro, Milão                              1
# Camp Nou, Barcelona                          1
# Stade de France, Saint-Denis                 1
# Estádio Monumental de Nuñez, Buenos Aires    1
# Rose Bowl, Pasadena                          1
# Wankdorf Stadium, Berna                      1
# Stadio Nazionale del PNF, Roma               1
# Wembley Stadium, Londres                     1
# International Stadium, Yokohama              1
# Name: Estádio, dtype: int64
